# %% [markdown]
# # LEVEL 1 TASK 3

# %%
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('newdata.csv')
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
#for creating bar chart as follows
plt.figure(figsize=(8,6))
plt.bar(df['Price range'].value_counts().index, df['Price range'].value_counts().values,color='skyblue')
plt.title('price ranges among restaurants')
plt.xlabel('Price Range')
plt.ylabel('Number of Restaurant')
plt.show()

# %%
numberof_restaurants=df['Restaurant Name'].count()
numberof_restaurants
# Out:
# 9551

# %%
pricerange_counts=df['Price range'].value_counts()
pricerange_counts
# Out:
# Price range
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: count, dtype: int64

# %%
perecentageof_restaurants=(pricerange_counts/numberof_restaurants)*100
print('Following is the result for perecentage of each price range category:')
perecentageof_restaurants
# Out:
# Following is the result for perecentage of each price range category:
# Price range
# 1    46.529159
# 2    32.593446
# 3    14.741912
# 4     6.135483
# Name: count, dtype: float64
